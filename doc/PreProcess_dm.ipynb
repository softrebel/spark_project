# %% [markdown]
# # Alzheimer DataSet

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
import seaborn as sns
path="D:/DataMiningProject/alzheimer.csv"

# %%
df= pd.read_csv(path)
df
# Out:
#            Group M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Nondemented   M   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1    Nondemented   M   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2       Demented   M   75    12  NaN  23.0  0.5  1678  0.736  1.046
# 3       Demented   M   76    12  NaN  28.0  0.5  1738  0.713  1.010
# 4       Demented   M   80    12  NaN  22.0  0.5  1698  0.701  1.034
# ..           ...  ..  ...   ...  ...   ...  ...   ...    ...    ...
# 368     Demented   M   82    16  1.0  28.0  0.5  1693  0.694  1.037
# 369     Demented   M   86    16  1.0  26.0  0.5  1688  0.675  1.040
# 370  Nondemented   F   61    13  2.0  30.0  0.0  1319  0.801  1.331
# 371  Nondemented   F   63    13  2.0  30.0  0.0  1327  0.796  1.323
# 372  Nondemented   F   65    13  2.0  30.0  0.0  1333  0.801  1.317
#
# [373 rows x 10 columns]

# %%
print(" Shape :",df.shape)# number of rows and colomns
print(" Types of data : \n",df.info())
D_Rows=df[df.duplicated()]
print("number of duplicated row : ",D_Rows.shape)
# Out:
#  Shape : (373, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Group   373 non-null    object
#  1   M/F     373 non-null    object
#  2   Age     373 non-null    int64
#  3   EDUC    373 non-null    int64
#  4   SES     354 non-null    float64
#  5   MMSE    371 non-null    float64
#  6   CDR     373 non-null    float64
#  7   eTIV    373 non-null    int64
#  8   nWBV    373 non-null    float64
#  9   ASF     373 non-null    float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 29.3+ KB
#  Types of data :
#  None
# number of duplicated row :  (0, 10)

# %%
for key in df.keys():
    print(f'{key}\n {list(df[key].unique())}')
# Out:
# Group
#  ['Nondemented', 'Demented', 'Converted']
# M/F
#  ['M', 'F']
# Age
#  [87, 88, 75, 76, 80, 90, 83, 85, 71, 73, 93, 95, 68, 69, 66, 78, 81, 82, 77, 86, 92, 84, 72, 61, 64, 74, 60, 62, 91, 79, 89, 70, 94, 97, 65, 67, 63, 96, 98]
# EDUC
#  [14, 12, 18, 16, 8, 20, 13, 6, 17, 15, 23, 11]
# SES
#  [2.0, nan, 3.0, 4.0, 1.0, 5.0]
# MMSE
#  [27.0, 30.0, 23.0, 28.0, 22.0, 29.0, 24.0, 21.0, 16.0, 25.0, 26.0, 15.0, 20.0, 19.0, 7.0, 4.0, 17.0, 18.0, nan]
# CDR
#  [0.0, 0.5, 1.0, 2.0]
# eTIV
# ...

# %% [markdown]
# # Data Description

# %%
fig, ax = plt.subplots()
df.hist(ax=ax)
fig.savefig('example.svg')
# Out:
# C:\Users\softeng\AppData\Local\Temp\ipykernel_16008\45364928.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax=ax)

# %%
sns.heatmap(df.isnull(),cbar=False,yticklabels=False,cmap='viridis')
plt.show()

# %%
corr=df.corr(method='spearman')
plt.figure(figsize=(15,15))
sns.heatmap(corr,vmax=0.8,linewidths=0.01,cmap='RdBu',linecolor='black')
plt.show()

# %%
sns.barplot(x=df.Group,y=df.SES)
plt.show()
sns.barplot(x=df.Group,y=df.CDR)
plt.show()
sns.barplot(x=df.Group,y=df.EDUC)
plt.show()
sns.barplot(x=df.Group,y=df.MMSE)
plt.show()
sns.barplot(x=df.Group,y=df.eTIV)
plt.show()
sns.barplot(x=df.Group,y=df.nWBV)
plt.show()
sns.barplot(x=df.Group,y=df.ASF)
plt.show()
sns.barplot(x=df.Group,y=df.Age)
plt.show()

# %%
df.dtypes
# Out:
# Group     object
# M/F       object
# Age        int64
# EDUC       int64
# SES      float64
# MMSE     float64
# CDR      float64
# eTIV       int64
# nWBV     float64
# ASF      float64
# dtype: object

# %%
df['Group']=df['Group'].astype('string')
df['M/F']=df['M/F'].astype('string')
df.dtypes
# Out:
# Group     string
# M/F       string
# Age        int64
# EDUC       int64
# SES      float64
# MMSE     float64
# CDR      float64
# eTIV       int64
# nWBV     float64
# ASF      float64
# dtype: object

# %%
df.value_counts()
# Out:
# Group        M/F  Age  EDUC  SES  MMSE  CDR  eTIV  nWBV   ASF
# Converted    F    65   12    2.0  30.0  0.5  1340  0.754  1.309    1
# Nondemented  F    83   16    2.0  29.0  0.0  1323  0.718  1.327    1
#                   80   8     5.0  27.0  0.0  1381  0.751  1.270    1
#                   79   18    2.0  29.0  0.0  1641  0.695  1.069    1
#                        16    1.0  29.0  0.0  1466  0.703  1.197    1
#                                                                   ..
# Demented     M    72   12    2.0  27.0  1.0  1432  0.684  1.226    1
#                   71   16    3.0  27.0  0.5  1479  0.750  1.187    1
#                              1.0  17.0  1.0  1562  0.685  1.123    1
#                        14    4.0  22.0  1.0  1332  0.679  1.317    1
# Nondemented  M    92   16    1.0  30.0  0.0  1662  0.682  1.056    1
# Length: 354, dtype: int64

# %%
df['M/F'].value_counts()
# Out:
# F    213
# M    160
# Name: M/F, dtype: Int64

# %%
df['Group'].value_counts()
# Out:
# Nondemented    190
# Demented       146
# Converted       37
# Name: Group, dtype: Int64

# %% [markdown]
# # Encode Label

# %%
# X=df[['M/F','Age','EDUC','SES','MMSE','CDR','eTIV','nWBV','ASF']].values

# y=df[['Group']].values
# print(y)
from sklearn import preprocessing
group_label_encoder=preprocessing.LabelEncoder()
group_label_encoder.fit(["Demented","Converted","Nondemented"])
df['Group'] = group_label_encoder.transform(df['Group'])

male_female_label_encoder=preprocessing.LabelEncoder()
male_female_label_encoder.fit(["F","M"])
df['M/F'] = male_female_label_encoder.transform(df['M/F'])
df
# Out:
#      Group  M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0        2    1   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1        2    1   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2        1    1   75    12  NaN  23.0  0.5  1678  0.736  1.046
# 3        1    1   76    12  NaN  28.0  0.5  1738  0.713  1.010
# 4        1    1   80    12  NaN  22.0  0.5  1698  0.701  1.034
# ..     ...  ...  ...   ...  ...   ...  ...   ...    ...    ...
# 368      1    1   82    16  1.0  28.0  0.5  1693  0.694  1.037
# 369      1    1   86    16  1.0  26.0  0.5  1688  0.675  1.040
# 370      2    0   61    13  2.0  30.0  0.0  1319  0.801  1.331
# 371      2    0   63    13  2.0  30.0  0.0  1327  0.796  1.323
# 372      2    0   65    13  2.0  30.0  0.0  1333  0.801  1.317
#
# [373 rows x 10 columns]

# %% [markdown]
# # Scatter Plot

# %%
import seaborn as sns
sns_plot =sns.pairplot(df)
sns_plot.figure.savefig("pairplot.svg")

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Outlier

# %%
outlier_removed_df=df.copy()
for key in ['MMSE','CDR','eTIV','nWBV','ASF','SES','EDUC','Age']:
    max=df['MMSE'].mean() + 3*df['MMSE'].std()
    min=df['MMSE'].mean() - 3*df['MMSE'].std()
    print(f'COLUMN: {key}')
    print(f"Highest allowed MMSE : {max}",)
    print(f"Lowest allowed MMSE : {min}",)
    new_df = df[~((df[key] < max) & (df[key] > min))]
df=outlier_removed_df.copy()
print(df.count)
# Out:
# COLUMN: MMSE
# Highest allowed MMSE : 1.3171757226369678
# Lowest allowed MMSE : 0.4818169513557065
# COLUMN: CDR
# Highest allowed MMSE : 1.3171757226369678
# Lowest allowed MMSE : 0.4818169513557065
# COLUMN: eTIV
# Highest allowed MMSE : 1.3171757226369678
# Lowest allowed MMSE : 0.4818169513557065
# COLUMN: nWBV
# Highest allowed MMSE : 1.3171757226369678
# Lowest allowed MMSE : 0.4818169513557065
# COLUMN: ASF
# Highest allowed MMSE : 1.3171757226369678
# Lowest allowed MMSE : 0.4818169513557065
# COLUMN: SES
# Highest allowed MMSE : 1.3171757226369678
# Lowest allowed MMSE : 0.4818169513557065
# COLUMN: EDUC
# Highest allowed MMSE : 1.3171757226369678
# Lowest allowed MMSE : 0.4818169513557065
# COLUMN: Age
# Highest allowed MMSE : 1.3171757226369678
# Lowest allowed MMSE : 0.4818169513557065
# <bound method DataFrame.count of      Group  M/F       Age      EDUC   SES      MMSE   CDR      eTIV      nWBV  \
# ...

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
scaled_values = scaler.fit_transform(df) 
df.loc[:,:] = scaled_values
df
# Out:
#      Group  M/F       Age      EDUC   SES      MMSE   CDR      eTIV      nWBV  \
# 0      1.0  1.0  0.710526  0.470588  0.25  0.884615  0.00  0.981069  0.269430
# 1      1.0  1.0  0.736842  0.470588  0.25  1.000000  0.00  1.000000  0.191710
# 2      0.5  1.0  0.394737  0.352941   NaN  0.730769  0.25  0.636971  0.476684
# 3      0.5  1.0  0.421053  0.352941   NaN  0.923077  0.25  0.703786  0.357513
# 4      0.5  1.0  0.526316  0.352941   NaN  0.692308  0.25  0.659243  0.295337
# ..     ...  ...       ...       ...   ...       ...   ...       ...       ...
# 368    0.5  1.0  0.578947  0.588235  0.00  0.923077  0.25  0.653675  0.259067
# 369    0.5  1.0  0.684211  0.588235  0.00  0.846154  0.25  0.648107  0.160622
# 370    1.0  0.0  0.026316  0.411765  0.25  1.000000  0.00  0.237194  0.813472
# 371    1.0  0.0  0.078947  0.411765  0.25  1.000000  0.00  0.246102  0.787565
# 372    1.0  0.0  0.131579  0.411765  0.25  1.000000  0.00  0.252784  0.813472
#
#           ASF
# 0    0.009845
# ...

# %% [markdown]
# # Dealing with missing values

# %%
current_col_frac=(df.isna().sum()/df.count()).to_dict()
current_col_frac
# Out:
# {'Group': 0.0,
#  'M/F': 0.0,
#  'Age': 0.0,
#  'EDUC': 0.0,
#  'SES': 0.05367231638418079,
#  'MMSE': 0.005390835579514825,
#  'CDR': 0.0,
#  'eTIV': 0.0,
#  'nWBV': 0.0,
#  'ASF': 0.0}

# %% [markdown]
# Data Count: 373
#
# SES  Missing Count: 19 -> 5 %
#
# MMSE Missing Count: 2 -> 0.5 %
#
# Desired Missing Count: 37 -> 10 %

# %%
max_missing_fraction=0.1
# current_col_frac={'SES':0.05,'MMSE':0.005}
for key in df.keys():
    if key == 'Group':
        continue
    current_frac=current_col_frac.get(key,0)
    frac=max_missing_fraction-current_frac
    if frac > 0:
        df.loc[df.sample(frac=frac).index,key] = pd.np.nan
    current_col_frac[key]=frac
df.isna().sum()
# Out:
# C:\Users\softeng\AppData\Local\Temp\ipykernel_16008\2520323413.py:7: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df.loc[df.sample(frac=frac).index,key] = pd.np.nan
# Group    37
# M/F      37
# Age      37
# EDUC     37
# SES      36
# MMSE     37
# CDR      37
# eTIV     37
# nWBV     37
# ASF      37
# dtype: int64

# %%
from sklearn import decomposition, datasets
from sklearn import tree
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

def grid_search(x,y):
    pca = decomposition.PCA()
    dec_tree = tree.DecisionTreeClassifier()
    pipe = Pipeline(steps=[('std_slc', std_slc),
                           ('pca', pca),
                           ('dec_tree', dec_tree)])
    n_components = list(range(1,X.shape[1]+1,1))
    criterion = ['gini', 'entropy']
    max_depth = [2,4,6,8,10,12]
    parameters = dict(pca__n_components=n_components,
                      dec_tree__criterion=criterion,
                      dec_tree__max_depth=max_depth)
    clf_GS = GridSearchCV(pipe, parameters)
    clf_GS.fit(X, y)
    print('Best Criterion:', clf_GS.best_estimator_.get_params()['dec_tree__criterion'])
    print('Best max_depth:', clf_GS.best_estimator_.get_params()['dec_tree__max_depth'])
    print('Best Number Of Components:', clf_GS.best_estimator_.get_params()['pca__n_components'])
    print(); print(clf_GS.best_estimator_.get_params()['dec_tree'])

# %%
x=df[['M/F','Age','EDUC','SES','MMSE','CDR','eTIV','nWBV','ASF']].to_numpy()
y=df[['Group']].to_numpy()

y
# Out:
# array([[nan],
#        [nan],
#        [0.5],
#        [0.5],
#        [0.5],
#        [1. ],
#        [1. ],
#        [1. ],
#        [1. ],
#        [nan],
#        [0.5],
#        [0.5],
#        [0.5],
#        [1. ],
#        [1. ],
#        [nan],
#        [0.5],
#        [0.5],
#        [0.5],
#        [1. ],
#        [1. ],
#        [1. ],
#        [1. ],
#        [1. ],
#        [1. ],
#        [0.5],
#        [0.5],
#        [0.5],
#        [0.5],
#        [1. ],
#        [1. ],
#        [1. ],
#        [1. ],
#        [0. ],
#        [nan],
#        [0. ],
#        [0. ],
#        [0. ],
#        [0. ],
#        [nan],
#        [0.5],
#        [1. ],
#        [1. ],
#        [0.5],
#        [0.5],
#        [0.5],
#        [0.5],
#        [1. ],
#        [1. ],
#        [1. ],
#        [1. ],
#        [0.5],
#        [0.5],
#        [1. ],
#        [1. ],
#        [1. ],
#        [1. ],
#        [0. ],
#        [0. ],
#        [0. ],
#        [0.5],
#        [0.5],
# ...
